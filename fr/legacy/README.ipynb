# %% [markdown]
# A demo to show latex.
#
#
# $\mu$

# %% [markdown]
# $$\mu$$

# %% [markdown]
# %%latex
# Some text
# \begin{equation}
# 1 + 1 + \sum_0^{infty} 0 = 4.
# \end{equation}
# Another text
# $$4 - 1 - \sum_0^{infty} 0 = 1;$$
# \[1 - 4 + \sum_0^{infty} 0 = -1;\]
# Voila!

# %%
n = 100
import numpy as np
res = [0] * n
k = 10
for i in range(1, n,1):
    q, r = divmod(10**i, 110000000000001)
    print(i, q, r)
    res[i] = r
# Out:
# 1 0 10
# 2 0 100
# 3 0 1000
# 4 0 10000
# 5 0 100000
# 6 0 1000000
# 7 0 10000000
# 8 0 100000000
# 9 0 1000000000
# 10 0 10000000000
# 11 0 100000000000
# 12 0 1000000000000
# 13 0 10000000000000
# 14 0 100000000000000
# 15 9 9999999999991
# 16 90 99999999999910
# 17 909 9999999999091
# 18 9090 99999999990910
# 19 90909 9999999909091
# 20 909090 99999999090910
# 21 9090909 9999990909091
# 22 90909090 99999909090910
# 23 909090909 9999090909091
# 24 9090909090 99990909090910
# 25 90909090909 9909090909091
# 26 909090909090 99090909090910
# 27 9090909090909 909090909091
# 28 90909090909090 9090909090910
# 29 909090909090900 90909090909100
# 30 9090909090909008 29090909090992
# 31 90909090909090082 70909090909918
# 32 909090909090900826 49090909099174
# 33 9090909090909008264 50909090991736
# 34 90909090909090082644 69090909917356
# 35 909090909090900826446 30909099173554
# 36 9090909090909008264462 89090991735538
# 37 90909090909090082644628 10909917355372
# ...

# %%
import matplotlib.pyplot as plt
m = 10
plt.plot(range(m), res[:m], '-*')
plt.show()

# %%
n = 100
import numpy as np
res = np.zeros((n, n))
for i in range(1, n,1):
    q1, r1 = divmod(10**i, 11)
    for j in range(1, n):
        q2, r2 = divmod(2**j, 11)
        print(i, j, q1, r1, q2, r2, r1==r2)
        res[i][j] = ()
# Out:
# 1 1 0 10 0 2 False
# 1 2 0 10 0 4 False
# 1 3 0 10 0 8 False
# 1 4 0 10 1 5 False
# 1 5 0 10 2 10 True
# 1 6 0 10 5 9 False
# 1 7 0 10 11 7 False
# 1 8 0 10 23 3 False
# 1 9 0 10 46 6 False
# 1 10 0 10 93 1 False
# 1 11 0 10 186 2 False
# 1 12 0 10 372 4 False
# 1 13 0 10 744 8 False
# 1 14 0 10 1489 5 False
# 1 15 0 10 2978 10 True
# 1 16 0 10 5957 9 False
# 1 17 0 10 11915 7 False
# 1 18 0 10 23831 3 False
# 1 19 0 10 47662 6 False
# 1 20 0 10 95325 1 False
# 1 21 0 10 190650 2 False
# 1 22 0 10 381300 4 False
# 1 23 0 10 762600 8 False
# 1 24 0 10 1525201 5 False
# 1 25 0 10 3050402 10 True
# 1 26 0 10 6100805 9 False
# 1 27 0 10 12201611 7 False
# 1 28 0 10 24403223 3 False
# 1 29 0 10 48806446 6 False
# 1 30 0 10 97612893 1 False
# 1 31 0 10 195225786 2 False
# 1 32 0 10 390451572 4 False
# 1 33 0 10 780903144 8 False
# 1 34 0 10 1561806289 5 False
# 1 35 0 10 3123612578 10 True
# 1 36 0 10 6247225157 9 False
# 1 37 0 10 12494450315 7 False
# 1 38 0 10 24988900631 3 False
# ...
